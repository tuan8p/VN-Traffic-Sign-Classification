# %% [markdown]
# # Kaggle bootstrap
#
# Clone/pull repo, install deps, set overrides. Enable 2×T4.

# %%
import os
os.environ.setdefault('WANDB_ENTITY', 'P4AIDS_ML')
os.environ.setdefault('WANDB_PROJECT', 'BTL')
# os.environ['DATA_ROOT'] = '/kaggle/input/YOUR_DATASET'
# !pip install -r requirements-kaggle.txt && pip install -e .
print('ready')
